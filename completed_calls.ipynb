# %%
import plotly.express as px
import pandas as pd

# %%
df = pd.read_csv("data/testData_month_orig.csv")

# %%
df
# Out:
#       date  max_emp  currently_working  currently_active  \
# 0   231001       18                 11                10
# 1   231002       18                 16                16
# 2   231003       18                 14                10
# 3   231004       18                 12                 9
# 4   231005       18                 18                10
# 5   231006       18                 12                10
# 6   231007       18                 17                17
# 7   231008       18                 15                 9
# 8   231009       18                 14                12
# 9   231010       18                 11                 9
# 10  231011       18                 18                11
# 11  231012       18                 18                16
# 12  231013       18                 16                10
# 13  231014       18                 11                10
# 14  231015       18                 14                13
# 15  231016       18                 10                10
# 16  231017       18                 14                10
# 17  231018       18                 18                17
# 18  231019       18                 18                18
# 19  231020       18                 12                11
# 20  231021       18                 18                12
# 21  231022       18                 14                10
# 22  231023       18                 14                10
# 23  231024       18                 11                 9
# 24  231025       18                 11                11
# 25  231026       18                 16                13
# 26  231027       18                 17                11
# 27  231028       18                 11                11
# 28  231029       18                 17                12
# 29  231030       18                 17                17
# 30  231031       18                 15                15
#
#     current_waiting_time  calls_at_9  calls_at_10  calls_at_11  calls_at_12  \
# 0                      2         101          128          112          110
# 1                      4         141          135           96          116
# 2                      2         115          136          142          128
# 3                      0         141          106           96          147
# 4                      5          92          113          103          122
# 5                      1          93          113          121           93
# 6                      1         100          114          121           95
# 7                      5         129          105          105          105
# 8                      0         118           90           97          108
# 9                      5         113          123          100           92
# 10                     5         124          125          120          148
# 11                     1         149          123          128           97
# 12                     5         143          129          133           92
# 13                     5         129          139          145          121
# 14                     4         142          136          101          116
# 15                     1         138          123          119          104
# 16                     0         138          100          123          135
# 17                     0         122          131           95          131
# 18                     0         140          123          100          119
# 19                     3         101          138          135          143
# 20                     0         144          132          137          136
# 21                     1         109          109          147          145
# 22                     3         102          143          105          129
# 23                     2         149          148          128           90
# 24                     3         147          143          134          100
# 25                     1         101           97          143          145
# 26                     1         111           91           93          123
# 27                     4          95          111           97          111
# 28                     0         128          122          121          144
# 29                     2          97          110          141           90
# 30                     2         125          139          120          136
#
#     calls_at_13  calls_at_14  calls_at_15  calls_at_16
# 0           117          143           97          108
# 1           111          148          149          146
# 2           116          147           96          116
# 3           124          110          128          103
# 4           143          118          142          149
# 5           123          124          148           97
# 6           129          101          133          150
# 7           134           95           94           95
# 8           107          110          119          138
# 9           115          115          124          111
# 10          121          112          140          126
# 11          102          116          128          101
# 12          135          139          148          118
# 13          104          100          115          113
# 14          117           92          129          131
# 15           99          111           90          131
# 16          101           90          131           98
# 17           97          122          131          128
# 18          104          130          113           91
# 19          118          101          110           98
# 20          136          111          117           92
# 21           93          113          132          144
# 22           93           95          138          121
# 23          135          105          118          135
# 24           90          117          136          147
# 25          145          132          149          150
# 26           99           90           97          142
# 27          140          116          146          128
# 28          125          138          149          133
# 29          114          113          138          141
# 30          140          104          106          141

# %%
import pandas as pd

# row_231001 = df['date'] = '231001'
row_0 = df.iloc[0]

print(row_0)
# Out:
# date                    231001
# max_emp                     18
# currently_working           11
# currently_active            10
# current_waiting_time         2
# calls_at_9                 101
# calls_at_10                128
# calls_at_11                112
# calls_at_12                110
# calls_at_13                117
# calls_at_14                143
# calls_at_15                 97
# calls_at_16                108
# Name: 0, dtype: object

# %%
# Sum the values of the three columns
total_calls = row_0['calls_at_9'] + row_0['calls_at_10'] + row_0['calls_at_11'] + row_0['calls_at_12'] + row_0['calls_at_13'] + row_0['calls_at_14']+ row_0['calls_at_15'] + row_0['calls_at_16']

print(f"Completed calls so far: {total_calls}")
# Out:
# Completed calls so far: 916
